# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
data = pd.read_csv('Districtwise_Drop_out.csv')
data.head()
# Out:
#          State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0   A & N Islands  2012-13         0.83          0.51          0.68
# 1   A & N Islands  2013-14         1.35          1.06          1.21
# 2   A & N Islands  2014-15         0.47          0.55          0.51
# 3  Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4  Andhra Pradesh  2013-14         4.31          4.39          4.35
#
#   Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 0     Uppe_r_Primary                1.09                1.23            5.57
# 1                 NR                1.54                0.51            8.36
# 2               1.44                1.95                1.69           11.47
# 3               3.21                3.51                3.36           12.21
# 4               3.46                4.12                3.78           11.95
#
#   Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# ...

# %%
data.shape
# Out:
# (109, 14)

# %%
data.tail()
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 104  West Bengal  2012-13         6.88          5.71           6.3
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
# 107    All India  2012-13         4.68          4.66          4.67
# 108    All India  2013-14         4.53          4.14          4.34
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 104               6.29                4.16                5.18
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
# 107                2.3                4.01                3.13
# 108               3.09                4.49                3.77
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 104           14.95            19.41             17.3             7.81
# ...

# %%
#missing data
data.isnull()
# Out:
#      State_UT   year  Primary_Boys  Primary_Girls  Primary_Total  \
# 0       False  False         False          False          False
# 1       False  False         False          False          False
# 2       False  False         False          False          False
# 3       False  False         False          False          False
# 4       False  False         False          False          False
# 5       False  False         False          False          False
# 6       False  False         False          False          False
# 7       False  False         False          False          False
# 8       False  False         False          False          False
# 9       False  False         False          False          False
# 10      False  False         False          False          False
# 11      False  False         False          False          False
# 12      False  False         False          False          False
# ...

# %%
#NaN place previous number placed 
data.fillna(method= 'pad')
# Out:
#                  State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0           A & N Islands  2012-13         0.83          0.51          0.68
# 1           A & N Islands  2013-14         1.35          1.06          1.21
# 2           A & N Islands  2014-15         0.47          0.55          0.51
# 3          Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4          Andhra Pradesh  2013-14         4.31          4.39          4.35
# 5          Andhra Pradesh  2014-15         6.57          6.89          6.72
# 6       Arunachal Pradesh  2013-14        11.54         10.22         10.89
# 7       Arunachal Pradesh  2012-13        15.84         14.44         15.16
# 8       Arunachal Pradesh  2014-15        11.51         10.09         10.82
# 9                   Assam  2012-13         7.02          5.46          6.24
# 10                  Assam  2013-14         8.19          6.68          7.44
# ...

# %%
print("old data frame lenth:", len(data))
# Out:
# old data frame lenth: 109

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 14 columns):
# State_UT               109 non-null object
# year                   109 non-null object
# Primary_Boys           109 non-null object
# Primary_Girls          109 non-null object
# Primary_Total          109 non-null object
# Upper Primary_Boys     109 non-null object
# Upper Primary_Girls    109 non-null object
# Upper Primary_Total    109 non-null object
# Secondary _Boys        109 non-null object
# Secondary _Girls       109 non-null object
# Secondary _Total       109 non-null object
# HrSecondary_Boys       109 non-null object
# HrSecondary_Girls      109 non-null object
# HrSecondary_Total      109 non-null object
# dtypes: object(14)
# memory usage: 12.0+ KB
