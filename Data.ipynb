# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
data = pd.read_csv('Districtwise_Basicdata.csv')

# %%
data.head()
# Out:
#       Year State Code                                         State Name  \
# 0     Year    Statecd                                          statename
# 1  2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2  2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3  2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4  2012-13         28  ANDHRA PRADESH                                ...
#
#   District Code                                      District Name  \
# 0        distcd                                           distname
# 1          3501  ANDAMANS                                      ...
# 2          3503  MIDDLE AND NORTH ANDAMANS                     ...
# 3          3502  NICOBARS                                      ...
# 4          2801  ADILABAD                                      ...
#
#   Number of Blocks Number of Clusters Number of Villages  \
# 0           blocks           clusters           villages
# ...

# %%
data.shape
# Out:
# (1325, 19)

# %%
data.tail()
# Out:
#          Year State Code                                         State Name  \
# 1320  2013-14         19  WEST BENGAL                                   ...
# 1321  2013-14         19  WEST BENGAL                                   ...
# 1322  2013-14         19  WEST BENGAL                                   ...
# 1323  2013-14         19  WEST BENGAL                                   ...
# 1324  2013-14         19  WEST BENGAL                                   ...
#
#      District Code                                      District Name  \
# 1320          1919  PURBA MEDINIPUR                               ...
# 1321          1914  PURULIYA                                      ...
# 1322          1921  SILIGURI                                      ...
# 1323          1918  SOUTH  TWENTY FOUR PARGAN                     ...
# 1324          1904  UTTAR DINAJPUR                                ...
#
#      Number of Blocks Number of Clusters Number of Villages  \
# ...

# %% [markdown]
# # Missing values

# %%
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
# NaN values is ture only
data.isnull()
# Out:
#        Year  State Code  State Name  District Code  District Name  \
# 0     False       False       False          False          False
# 1     False       False       False          False          False
# 2     False       False       False          False          False
# 3     False       False       False          False          False
# 4     False       False       False          False          False
# 5     False       False       False          False          False
# 6     False       False       False          False          False
# 7     False       False       False          False          False
# 8     False       False       False          False          False
# 9     False       False       False          False          False
# 10    False       False       False          False          False
# 11    False       False       False          False          False
# 12    False       False       False          False          False
# ...

# %%
#NaN values is false  only
data.notnull()
# Out:
#       Year  State Code  State Name  District Code  District Name  \
# 0     True        True        True           True           True
# 1     True        True        True           True           True
# 2     True        True        True           True           True
# 3     True        True        True           True           True
# 4     True        True        True           True           True
# 5     True        True        True           True           True
# 6     True        True        True           True           True
# 7     True        True        True           True           True
# 8     True        True        True           True           True
# 9     True        True        True           True           True
# 10    True        True        True           True           True
# 11    True        True        True           True           True
# 12    True        True        True           True           True
# ...

# %%
#NaN place in 99 Values
data.replace(to_replace= np.nan, value = 99)
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
#NaN place previous number placed 
data.fillna(method= 'pad')
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
# NaN place below value placed
data.fillna(method= 'bfill')
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
#NaN line is removed
data.dropna()
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data1 = data.dropna()
data1
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
#NaN all print
data.dropna(how = 'all')
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
# this only one same colums print
data.dropna(axis = 1)
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
print("old data frame lenth:", len(data))
# Out:
# old data frame lenth: 1325

# %%
print("new data frame lenth:",len(data1))
# Out:
# new data frame lenth: 1251

# %%
print("no of rows with at least 1 Na value:", len(data)- len(data1))
# Out:
# no of rows with at least 1 Na value: 74

# %%
data.head()
# Out:
#       Year State Code                                         State Name  \
# 0     Year    Statecd                                          statename
# 1  2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2  2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3  2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4  2012-13         28  ANDHRA PRADESH                                ...
#
#   District Code                                      District Name  \
# 0        distcd                                           distname
# 1          3501  ANDAMANS                                      ...
# 2          3503  MIDDLE AND NORTH ANDAMANS                     ...
# 3          3502  NICOBARS                                      ...
# 4          2801  ADILABAD                                      ...
#
#   Number of Blocks Number of Clusters Number of Villages  \
# 0           blocks           clusters           villages
# ...

# %% [markdown]
# # Duplicate data

# %%
data.sort_values("Year", inplace= True)
data.head()
# Out:
#         Year State Code                                         State Name  \
# 662  2012-13         19  WEST BENGAL                                   ...
# 437  2012-13         21  ORISSA                                        ...
# 438  2012-13         21  ORISSA                                        ...
# 439  2012-13         21  ORISSA                                        ...
# 440  2012-13         21  ORISSA                                        ...
#
#     District Code                                      District Name  \
# 662          1904  UTTAR DINAJPUR                                ...
# 437          2102  JHARSUGUDA                                    ...
# 438          2126  KALAHANDI                                     ...
# 439          2121  KANDHAMAL                                     ...
# 440          2110  KENDRAPARA                                    ...
#
#     Number of Blocks Number of Clusters Number of Villages  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 662 to 0
# Data columns (total 19 columns):
# Year                           1325 non-null object
# State Code                     1325 non-null object
# State Name                     1325 non-null object
# District Code                  1325 non-null object
# District Name                  1325 non-null object
# Number of Blocks               1325 non-null object
# Number of Clusters             1325 non-null object
# Number of Villages             1325 non-null object
# Total Number of Schools        1325 non-null object
# Total Poulation                1269 non-null object
# 0-6 Population                 1267 non-null object
# Percentage Urban Population    1263 non-null object
# Sexratio                       1269 non-null object
# Sex Ratio 0-6                  1267 non-null object
# Decadal Growth Rate            1269 non-null object
# Percentage SC Population       1257 non-null object
# ...

# %%
data
# Out:
#         Year State Code                                         State Name  \
# 662  2012-13         19  WEST BENGAL                                   ...
# 437  2012-13         21  ORISSA                                        ...
# 438  2012-13         21  ORISSA                                        ...
# 439  2012-13         21  ORISSA                                        ...
# 440  2012-13         21  ORISSA                                        ...
# 441  2012-13         21  ORISSA                                        ...
# 442  2012-13         21  ORISSA                                        ...
# 443  2012-13         21  ORISSA                                        ...
# 436  2012-13         21  ORISSA                                        ...
# 444  2012-13         21  ORISSA                                        ...
# 446  2012-13         21  ORISSA                                        ...
# ...

# %% [markdown]
# # string manipalations

# %%
data = pd.read_csv('Districtwise_Basicdata.csv')
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data.isnull()
# Out:
#        Year  State Code  State Name  District Code  District Name  \
# 0     False       False       False          False          False
# 1     False       False       False          False          False
# 2     False       False       False          False          False
# 3     False       False       False          False          False
# 4     False       False       False          False          False
# 5     False       False       False          False          False
# 6     False       False       False          False          False
# 7     False       False       False          False          False
# 8     False       False       False          False          False
# 9     False       False       False          False          False
# 10    False       False       False          False          False
# 11    False       False       False          False          False
# 12    False       False       False          False          False
# ...

# %%
# NaN place below value placed
data.fillna(method= 'bfill')
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data.dropna(inplace = True)
sub = 'a'
data["indexes"] = data["State Name"].str.find(sub)
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
sub = 'er'
start = 2
data["indexes"] = data["State Name"].str.find(sub, start)
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %% [markdown]
# # Data transformation

# %%
# this used in dataframe
data
# Out:
#          Year State Code                                         State Name  \
# 0        Year    Statecd                                          statename
# 1     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 2     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 3     2012-13         35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4     2012-13         28  ANDHRA PRADESH                                ...
# 5     2012-13         28  ANDHRA PRADESH                                ...
# 6     2012-13         28  ANDHRA PRADESH                                ...
# 7     2012-13         28  ANDHRA PRADESH                                ...
# 8     2012-13         28  ANDHRA PRADESH                                ...
# 9     2012-13         28  ANDHRA PRADESH                                ...
# 10    2012-13         28  ANDHRA PRADESH                                ...
# ...

# %%
data['Number of Blocks']
# Out:
# 0       blocks
# 1            3
# 2            3
# 3            3
# 4           52
# 5           63
# 6           66
# 7           51
# 8           60
# 9           57
# 10          16
# 11          57
# 12          46
# 13          50
# 14          54
# 15          64
# 16          46
# 17          59
# 18          46
# 19          36
# 20          56
# 21          37
# 22          38
# 23          43
# 24          34
# 25          51
# 26          46
# 27           4
# 28           7
# 29           3
#          ...
# 1294         9
# 1295         4
# 1296         6
# 1297        15
# 1298         6
# 1299         8
# 1300         8
# 1301         3
# 1302         9
# 1303         7
# 1304         6
# 1305        25
# 1306        42
# 1307        25
# 1308        10
# 1309        12
# 1310        17
# 1311        31
# 1312        17
# 1313        18
# 1314         1
# 1315        17
# 1316        33
# 1317        27
# 1318        50
# 1319        37
# 1320        30
# ...
